# %% [markdown]
# # Dimension Reduction

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Principal components analysis (PCA)
#
# * It is a useful method for dimension reduction, especially when the number of variables is large.
# * PCA is intended for use with numerical variables.
#    * For categorical variables, other methods such as correspondence analysis are more suitable.

# %%
Path = 'C:\\Users\\npradah\\Documents\\Team30_ArtificialmenteInteligentes\\Semana 4\\default of credit card clients.csv'

# %%
credit_df = pd.read_csv(Path, index_col = 0)
credit_df.rename(columns = {'X1' : 'credit', 'X2': 'gender', 'X3': 'education', 'X4': 'marital', 'X5': 'age',
                      'X6' : 'hpp Sep 2005', 'X7' : 'hpp Aug 2005', 'X8' : 'hpp Jul 2005', 'X9' : 'hpp Jun 2005', 'X10' : 'hpp May 2005', 'X11' : 'hpp Apr 2005', 
                      'X12' : 'abs Sep 2005', 'X13' : 'abs Aug 2005', 'X14' : 'abs Jul 2005', 'X15' : 'abs Jun 2005', 'X16' : 'abs May 2005', 'X17' : 'abs Apr 2005', 
                      'X18' : 'app Sep 2005', 'X19' : 'app Aug 2005', 'X20' : 'app Jul 2005', 'X21' : 'app Jun 2005', 'X22' : 'app May 2005', 'X23' : 'app Apr 2005'}, inplace = True)

df = credit_df.copy()
df
# Out:
#        credit  gender  education  marital   age  hpp Sep 2005  hpp Aug 2005  \
# ID
# 1       20000     2.0        2.0      1.0  24.0           2.0           2.0
# 2      120000     2.0        2.0      2.0  26.0          -1.0           2.0
# 3       90000     2.0        2.0      2.0  34.0           0.0           0.0
# 4       50000     2.0        2.0      1.0  37.0           0.0           0.0
# 5       50000     1.0        2.0      1.0  57.0          -1.0           0.0
# ...       ...     ...        ...      ...   ...           ...           ...
# 29996  220000     1.0        3.0      1.0  39.0           0.0           0.0
# 29997  150000     1.0        3.0      2.0  43.0          -1.0          -1.0
# 29998   30000     1.0        2.0      2.0  37.0           4.0           3.0
# 29999   80000     1.0        3.0      1.0  41.0           1.0          -1.0
# 30000   50000     1.0        2.0      1.0  46.0           0.0           0.0
#
#        hpp Jul 2005  hpp Jun 2005  hpp May 2005  ...  abs Jun 2005  \
# ID                                               ...
# 1              -1.0          -1.0          -2.0  ...           0.0
# 2               0.0           0.0           0.0  ...        3272.0
# 3               0.0           0.0           0.0  ...       14331.0
# 4               0.0           0.0           0.0  ...       28314.0
# 5              -1.0           0.0           0.0  ...       20940.0
# ...             ...           ...           ...  ...           ...
# 29996           0.0           0.0           0.0  ...       88004.0
# 29997          -1.0          -1.0           0.0  ...        8979.0
# 29998           2.0          -1.0           0.0  ...       20878.0
# 29999           0.0           0.0           0.0  ...       52774.0
# 30000           0.0           0.0           0.0  ...       36535.0
#
#        abs May 2005  abs Apr 2005  app Sep 2005  app Aug 2005  app Jul 2005  \
# ID
# 1               0.0           0.0           0.0         689.0           0.0
# 2            3455.0        3261.0           0.0        1000.0        1000.0
# 3           14948.0       15549.0        1518.0        1500.0        1000.0
# 4           28959.0       29547.0        2000.0        2019.0        1200.0
# 5           19146.0       19131.0        2000.0       36681.0       10000.0
# ...             ...           ...           ...           ...           ...
# 29996       31237.0       15980.0        8500.0       20000.0        5003.0
# 29997        5190.0           0.0        1837.0        3526.0        8998.0
# 29998       20582.0       19357.0           0.0           0.0       22000.0
# 29999       11855.0       48944.0       85900.0        3409.0        1178.0
# 30000       32428.0       15313.0        2078.0        1800.0        1430.0
#
#        app Jun 2005  app May 2005  app Apr 2005    Y
# ID
# 1               0.0           0.0           0.0  1.0
# 2            1000.0           0.0        2000.0  1.0
# 3            1000.0        1000.0        5000.0  0.0
# 4            1100.0        1069.0        1000.0  0.0
# 5            9000.0         689.0         679.0  0.0
# ...             ...           ...           ...  ...
# 29996        3047.0        5000.0        1000.0  0.0
# 29997         129.0           0.0           0.0  0.0
# 29998        4200.0        2000.0        3100.0  1.0
# 29999        1926.0       52964.0        1804.0  1.0
# 30000        1000.0        1000.0        1000.0  1.0
#
# [30000 rows x 24 columns]

# %%
df.shape
# Out:
# (30000, 24)

# %% [markdown]
# For each client, the data include 24 numerical variables, and we are interested in reducing this dimension.
#
# Principal Component Analysis can tell you what variables in your data are the most important.

# %%
df.dropna(axis = 0, inplace = True) # axis 1 is columns / axis 0 is rows. dat
df
# Out:
#        credit  gender  education  marital   age  hpp Sep 2005  hpp Aug 2005  \
# ID
# 1       20000     2.0        2.0      1.0  24.0           2.0           2.0
# 2      120000     2.0        2.0      2.0  26.0          -1.0           2.0
# 3       90000     2.0        2.0      2.0  34.0           0.0           0.0
# 4       50000     2.0        2.0      1.0  37.0           0.0           0.0
# 5       50000     1.0        2.0      1.0  57.0          -1.0           0.0
# ...       ...     ...        ...      ...   ...           ...           ...
# 29996  220000     1.0        3.0      1.0  39.0           0.0           0.0
# 29997  150000     1.0        3.0      2.0  43.0          -1.0          -1.0
# 29998   30000     1.0        2.0      2.0  37.0           4.0           3.0
# 29999   80000     1.0        3.0      1.0  41.0           1.0          -1.0
# 30000   50000     1.0        2.0      1.0  46.0           0.0           0.0
#
#        hpp Jul 2005  hpp Jun 2005  hpp May 2005  ...  abs Jun 2005  \
# ID                                               ...
# 1              -1.0          -1.0          -2.0  ...           0.0
# 2               0.0           0.0           0.0  ...        3272.0
# 3               0.0           0.0           0.0  ...       14331.0
# 4               0.0           0.0           0.0  ...       28314.0
# 5              -1.0           0.0           0.0  ...       20940.0
# ...             ...           ...           ...  ...           ...
# 29996           0.0           0.0           0.0  ...       88004.0
# 29997          -1.0          -1.0           0.0  ...        8979.0
# 29998           2.0          -1.0           0.0  ...       20878.0
# 29999           0.0           0.0           0.0  ...       52774.0
# 30000           0.0           0.0           0.0  ...       36535.0
#
#        abs May 2005  abs Apr 2005  app Sep 2005  app Aug 2005  app Jul 2005  \
# ID
# 1               0.0           0.0           0.0         689.0           0.0
# 2            3455.0        3261.0           0.0        1000.0        1000.0
# 3           14948.0       15549.0        1518.0        1500.0        1000.0
# 4           28959.0       29547.0        2000.0        2019.0        1200.0
# 5           19146.0       19131.0        2000.0       36681.0       10000.0
# ...             ...           ...           ...           ...           ...
# 29996       31237.0       15980.0        8500.0       20000.0        5003.0
# 29997        5190.0           0.0        1837.0        3526.0        8998.0
# 29998       20582.0       19357.0           0.0           0.0       22000.0
# 29999       11855.0       48944.0       85900.0        3409.0        1178.0
# 30000       32428.0       15313.0        2078.0        1800.0        1430.0
#
#        app Jun 2005  app May 2005  app Apr 2005    Y
# ID
# 1               0.0           0.0           0.0  1.0
# 2            1000.0           0.0        2000.0  1.0
# 3            1000.0        1000.0        5000.0  0.0
# 4            1100.0        1069.0        1000.0  0.0
# 5            9000.0         689.0         679.0  0.0
# ...             ...           ...           ...  ...
# 29996        3047.0        5000.0        1000.0  0.0
# 29997         129.0           0.0           0.0  0.0
# 29998        4200.0        2000.0        3100.0  1.0
# 29999        1926.0       52964.0        1804.0  1.0
# 30000        1000.0        1000.0        1000.0  1.0
#
# [29958 rows x 24 columns]

# %% [markdown]
# We focus first on two variables: `education` and consumer `age`:

# %%
ndf = df[['education', 'age']]
ndf.corr()
# Out:
#            education       age
# education   1.000000  0.175079
# age         0.175079  1.000000

# %%
round(df.education.mean(),2)
# Out:
# 1.85

# %%
round(df.age.mean(),2)
# Out:
# 35.48

# %%
Varience = np.cov([df.education, df.age])
Varience
# Out:
# array([[ 0.62484455,  1.27521564],
#        [ 1.27521564, 84.90367153]])

# %%
ndf = df[['education','age']]
ndf.var().sum()
# Out:
# 85.52851607722928

# %%
t= ndf.var().sum()
varM =Varience[0][0]
varA = Varience[1][1]

# %%
print('Total Varience \t\t\t:', t.round(2) )
print('Varience prop. of education \t:', ((varM/t)*100).round(2),'%' )
print('Varience prop. of age \t:', ((varA/t)*100).round(2),'%' )
# Out:
# Total Varience 			: 85.53
# Varience prop. of education 	: 0.73 %
# Varience prop. of age 	: 99.27 %

# %% [markdown]
# If we drop `age` for the sake of dimension reduction, we lose at least 99.68% of the total variability.

# %%
ndf.corr().round(2)
# Out:
#            education   age
# education       1.00  0.18
# age             0.18  1.00

# %% [markdown]
# Roughly speaking, 18% of the total variation in both variables is actually “co-variation,” or variation in one variable that is duplicated by similar variation in the other variable.
#
# Can we use this fact to reduce the number of variables, while making maximum use of their unique contributions to the overall variation?
#
# Since there is redundancy in the information that the two variables contain, it might be possible to reduce the `two variables` to a `single variable` `without losing` `too much` information.
#
# The idea in PCA is to find a linear combination of the two variables that contains most, even if not all, of the information, so that this new variable can replace the two original variables.

# %% [markdown]
# The line `z1 (first principal component = PC1)` is the direction in which the variability of the points is largest.
#
# The `z2 (second principal component = PC2)`-axis is chosen to be perpendicular to the z1-axis.

# %%
import seaborn as sns

# %%
p = sns.regplot(data = df,  
                x = df.education, 
                y = df.age
               ) 

p
# Out:
# <AxesSubplot:xlabel='education', ylabel='age'>

# %%
import numpy as np
from sklearn.decomposition import PCA

# %%
pcs = PCA(n_components=2)

pcs.fit(df[['education', 'age']])

pcsSummary = pd.DataFrame({'Standard deviation': np.sqrt(pcs.explained_variance_),
                          'Proportion of variance': pcs.explained_variance_ratio_,
                          'Cumulative proportion': np.cumsum(pcs.explained_variance_ratio_)#column 
                          }
                          )
pcsSummary
# Out:
#    Standard deviation  Proportion of variance  Cumulative proportion
# 0            9.215366                 0.99292                0.99292
# 1            0.778173                 0.00708                1.00000

# %%
pcsSummary = pcsSummary.transpose()
pcsSummary.round(2)
# Out:
#                            0     1
# Standard deviation      9.22  0.78
# Proportion of variance  0.99  0.01
# Cumulative proportion   0.99  1.00

# %%
pcsSummary.columns = ['PC1', 'PC2']
pcsSummary = pcsSummary.round(4)
pcsSummary
# Out:
#                            PC1     PC2
# Standard deviation      9.2154  0.7782
# Proportion of variance  0.9929  0.0071
# Cumulative proportion   0.9929  1.0000

# %% [markdown]
# The summary gives the reallocated variance:
# * `z1` accounts for 99.74% of the total variability and
# * `z2` for the remaining 0.26%.
#
# Therefore, if we drop `z2 = PC2`, we still maintain 99.74% of the total variability.
#
# https://www.youtube.com/watch?v=FgakZw6K1QQ

# %% [markdown]
# ### Scree Plot

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
PC_components = np.arange(pcs.n_components_) + 1
#PC_components

_ = sns.set(style = 'whitegrid', 
            font_scale = 1.2
            )

fig, ax = plt.subplots(figsize=(10, 7))

_ = sns.barplot(x = PC_components, 
                y = pcs.explained_variance_ratio_, 
                color = 'b'
                )

_ = sns.lineplot(x = PC_components-1, 
                 y = np.cumsum(pcs.explained_variance_ratio_), 
                 color = 'black', 
                 linestyle = '-', 
                 linewidth = 2, 
                 marker = 'o', 
                 markersize = 8
                 )

plt.title('Scree Plot')
plt.xlabel('N-th Principal Component')
plt.ylabel('Variance Explained')
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# * The first principal component has the largest possible variance (that is, accounts for as much of the variability in the data as possible)
# * Each succeeding component, in turn, has the highest variance possible under the constraint that it is orthogonal the preceding components.

# %%
pcs.components_.round(4) #is the set of all eigenvectors for your projection space (one eigenvector for each principal component).
# Out:
# array([[ 0.0151,  0.9999],
#        [ 0.9999, -0.0151]])

# %%
pcsComponents_df = pd.DataFrame(pcs.components_.transpose(), 
                                columns=['PC1', 'PC2'],
                                index=['education', 'age']
                                )
pcsComponents_df
# Out:
#                 PC1       PC2
# education  0.015126  0.999886
# age        0.999886 -0.015126

# %% [markdown]
# > The first column here shows coefficients of linear combination that defines PC1 (z1)
#
# > The second column shows coefficients for PC2 (z2).

# %% [markdown]
# The weights are used to compute principal component scores, which are the projected values of education and age onto the new axes (after subtracting the means).
#
# * The average education across the 29958 clients is `1.85` and the average consumer age is `35.48`.
#
# * The first column is the projection onto z1 using the weights (0.015126, 0.999886).
#
#     * The second column is the projection onto z2 using the weights (0.999886, -0.015126).
#
# For example:
#
# First, we need to center the original variables by subtracting column means
# (2 − `1.85`)   & (24 − `35.48`)
#
# Second multiply them with corresponding Principal components.
#
# The first score for the 100% Bran cereal (with 2 education and a age of 24) is
# $$( 0.015126)(2 − 1.85) + (0.999886)(24 − 35.48) = -11.4764224$$
# $$ Z_i = a_{i1} (X_1 - \bar{X_1}) + a_{i2} (X_2 - \bar{X_2}) + \cdots + a_{in} (X_n - \bar{X_n}) ; i = 1, 2, 3, \cdots n$$

# %%
scores = pd.DataFrame(pcs.transform(df[['education', 'age']]),
                      columns=['x', 'y']
                      )
scores.head()
# Out:
#            x         y
# 0 -11.479908  0.320584
# 1  -9.480137  0.290333
# 2  -1.481052  0.169327
# 3   1.518605  0.123950
# 4  21.516317 -0.178565

# %%
x = (0.015126)*(2-1.85)+(0.999886)*(24-35.48)

y = (0.999886)*(2-1.85)+(-0.015126)*(24-35.48)

# %%
print('For the PC1\n \t x = ', x, '\n\t y = ', y)
# Out:
# For the PC1
#  	 x =  -11.476422379999997
# 	 y =  0.32362937999999986

# %%
scores.x.mean()
# Out:
# -6.003016437041236e-15

# %%
scores.y.sum()
# Out:
# -1.1652900866465643e-12

# %% [markdown]
# The sum of the variances `var(z1) + var(z2)` is equal to the sum of the variances of the original variables, `var(education) + var(age)`.

# %%
scores.x.var() + scores.y.var()
# Out:
# 85.52851607722177

# %%
df.education.var() + df.age.var()
# Out:
# 85.52851607722928

# %%
round(((scores.x.var()/
  (scores.x.var()+scores.y.var())
 )*100),0)
# Out:
# 99.0

# %%
pcs = PCA()
pcs.fit(credit_df.iloc[:, 3:].dropna(axis=0))
pcsSummary_df = pd.DataFrame({'Standard deviation': np.sqrt(pcs.explained_variance_),
                             'Proportion of variance': pcs.explained_variance_ratio_,
                             'Cumulative proportion': np.cumsum(pcs.explained_variance_ratio_)
                             })
pcsSummary_df = pcsSummary_df.transpose()
pcsSummary_df
# Out:
#                                    0             1             2   \
# Standard deviation      155846.188861  37338.865667  27844.266356
# Proportion of variance       0.848685      0.048717      0.027091
# Cumulative proportion        0.848685      0.897402      0.924493
#
#                                   3             4             5   \
# Standard deviation      21441.524438  20314.800613  18521.060369
# Proportion of variance      0.016064      0.014420      0.011986
# Cumulative proportion       0.940557      0.954978      0.966964
#
#                                   6             7             8   \
# Standard deviation      17040.622246  16328.049834  11623.455093
# Proportion of variance      0.010147      0.009316      0.004721
# Cumulative proportion       0.977111      0.986427      0.991147
#
#                                   9   ...           11            12  \
# Standard deviation      10434.984690  ...  8200.532958  9.199680e+00
# Proportion of variance      0.003805  ...     0.002350  2.957329e-09
# Cumulative proportion       0.994952  ...     1.000000  1.000000e+00
#
#                                   13            14            15  \
# Standard deviation      2.254529e+00  9.428598e-01  7.333240e-01
# Proportion of variance  1.776094e-10  3.106336e-11  1.879083e-11
# Cumulative proportion   1.000000e+00  1.000000e+00  1.000000e+00
#
#                                   16            17            18  \
# Standard deviation      5.967781e-01  5.121604e-01  4.749605e-01
# Proportion of variance  1.244458e-11  9.165711e-12  7.882595e-12
# Cumulative proportion   1.000000e+00  1.000000e+00  1.000000e+00
#
#                                   19            20
# Standard deviation      4.186401e-01  3.861287e-01
# Proportion of variance  6.124011e-12  5.209768e-12
# Cumulative proportion   1.000000e+00  1.000000e+00
#
# [3 rows x 21 columns]

# %% [markdown]
# ### Scree Plot

# %%
PC_components = np.arange(pcs.n_components_) + 1
#PC_components

_ = sns.set(style = 'whitegrid', 
            font_scale = 1.2
            )

fig, ax = plt.subplots(figsize=(10, 7))

_ = sns.barplot(x = PC_components, 
                y = pcs.explained_variance_ratio_, 
                color = 'b'
                )

_ = sns.lineplot(x = PC_components-1, 
                 y = np.cumsum(pcs.explained_variance_ratio_), 
                 color = 'black', 
                 linestyle = '-', 
                 linewidth = 2, 
                 marker = 'o', 
                 markersize = 8
                 )

plt.title('Scree Plot')
plt.xlabel('N-th Principal Component')
plt.ylabel('Variance Explained')
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# Note that the first three components account for more than 92% of the total variation associated with all 24 of the original variables.

# %%
#pcsSummary_df.iloc[1][0]+pcsSummary_df.iloc[1][1]+pcsSummary_df.iloc[1][2]
#OR
((pcsSummary_df.iloc[2][2])*100).round(0)
#type(pcsSummary_df)
# Out:
# 92.0

# %% [markdown]
# In fact, the first two principal components alone capture 89.74% of the total variation.

# %%
#pcsSummary_df.iloc[1][0]+pcsSummary_df.iloc[1][1]
#OR
((pcsSummary_df.iloc[2][1])*100).round(2)
# Out:
# 89.74

# %%
pcsSummary_df.columns = ['PC{}'.format(i) for i in range(1, len(pcsSummary_df.columns) + 1)]
pcsSummary_df.round(4)
# Out:
#                                 PC1         PC2         PC3         PC4  \
# Standard deviation      155846.1889  37338.8657  27844.2664  21441.5244
# Proportion of variance       0.8487      0.0487      0.0271      0.0161
# Cumulative proportion        0.8487      0.8974      0.9245      0.9406
#
#                                PC5         PC6         PC7         PC8  \
# Standard deviation      20314.8006  18521.0604  17040.6222  16328.0498
# Proportion of variance      0.0144      0.0120      0.0101      0.0093
# Cumulative proportion       0.9550      0.9670      0.9771      0.9864
#
#                                PC9        PC10  ...       PC12    PC13  \
# Standard deviation      11623.4551  10434.9847  ...  8200.5330  9.1997
# Proportion of variance      0.0047      0.0038  ...     0.0023  0.0000
# Cumulative proportion       0.9911      0.9950  ...     1.0000  1.0000
#
#                           PC14    PC15    PC16    PC17    PC18   PC19    PC20  \
# Standard deviation      2.2545  0.9429  0.7333  0.5968  0.5122  0.475  0.4186
# Proportion of variance  0.0000  0.0000  0.0000  0.0000  0.0000  0.000  0.0000
# Cumulative proportion   1.0000  1.0000  1.0000  1.0000  1.0000  1.000  1.0000
#
#                           PC21
# Standard deviation      0.3861
# Y            -1.985910e-02 -5.756094e-02 -3.711641e-02 -9.900990e-01
#
# [21 rows x 21 columns]

# %% [markdown]
# Here, it is clear that:
# * the first principal component is dominated by the 'abs Sep 2005':
#   * it has the highest (in this case, negative) weight (4.465646e-01).
#
#   * This means that the first principal component is in fact measuring how much 'abs Jun 2005' Amount of bill statement (NT dollar) has the client.
#
# * The second principal component seems to be measuring 'abs Sep 2005'.
#
# **Normalize before applying PCA!!!**

# %% [markdown]
# * Normalize and then performing PCA on the correlation matrix instead of the covariance matrix.
# * Using the correlation matrix means that you are opeage on the normalized data.

# %%
from sklearn import preprocessing

# %% [markdown]
# #### Normalize the 24 variables due to the different scales of the variables and then perform PCA (or equivalently, we use PCA applied to the correlation matrix)

# %%
credit_df.iloc[:, 3:].head()
# Out:
#     marital   age  hpp Sep 2005  hpp Aug 2005  hpp Jul 2005  hpp Jun 2005  \
# ID
# 1       1.0  24.0           2.0           2.0          -1.0          -1.0
# 2       2.0  26.0          -1.0           2.0           0.0           0.0
# 3       2.0  34.0           0.0           0.0           0.0           0.0
# 4       1.0  37.0           0.0           0.0           0.0           0.0
# 5       1.0  57.0          -1.0           0.0          -1.0           0.0
#
#     hpp May 2005  hpp Apr 2005  abs Sep 2005  abs Aug 2005  ...  abs Jun 2005  \
# ID                                                          ...
# 1           -2.0          -2.0        3913.0        3102.0  ...           0.0
# 2            0.0           2.0        2682.0        1725.0  ...        3272.0
# 3            0.0           0.0       29239.0       14027.0  ...       14331.0
# 4            0.0           0.0       46990.0       48233.0  ...       28314.0
# 5            0.0           0.0        8617.0        5670.0  ...       20940.0
#
#     abs May 2005  abs Apr 2005  app Sep 2005  app Aug 2005  app Jul 2005  \
# ID
# 1            0.0           0.0           0.0         689.0           0.0
# 2         3455.0        3261.0           0.0        1000.0        1000.0
# 3        14948.0       15549.0        1518.0        1500.0        1000.0
# 4        28959.0       29547.0        2000.0        2019.0        1200.0
# 5        19146.0       19131.0        2000.0       36681.0       10000.0
#
#     app Jun 2005  app May 2005  app Apr 2005    Y
# ID
# 1            0.0           0.0           0.0  1.0
# 2         1000.0           0.0        2000.0  1.0
# 3         1000.0        1000.0        5000.0  0.0
# 4         1100.0        1069.0        1000.0  0.0
# 5         9000.0         689.0         679.0  0.0
#
# [5 rows x 21 columns]

# %%
pcs = PCA()
pcs.fit(preprocessing.scale(credit_df.iloc[:, 3:].dropna(axis=0))) 
                # Standardize a dataset along any axis.
                # Center to the mean and component wise scale to unit variance.
# Out:
# PCA()

# %%
pcsSummary_df = pd.DataFrame({'Standard deviation': np.sqrt(pcs.explained_variance_),
                             'Proportion of variance': pcs.explained_variance_ratio_,
                             'Cumulative proportion': np.cumsum(pcs.explained_variance_ratio_)
                             })

pcsSummary_df = pcsSummary_df.transpose()
pcsSummary_df.columns = ['PC{}'.format(i) for i in range(1, len(pcsSummary_df.columns) + 1)]
pcsSummary_df.round(4)
# Out:
#                            PC1     PC2     PC3     PC4     PC5     PC6  \
# Standard deviation      2.5543  1.9575  1.2307  1.1826  0.9747  0.9507
# Proportion of variance  0.3107  0.1825  0.0721  0.0666  0.0452  0.0430
# Cumulative proportion   0.3107  0.4931  0.5652  0.6318  0.6771  0.7201
#
#                            PC7     PC8     PC9    PC10  ...    PC12    PC13  \
# Standard deviation      0.9417  0.9339  0.8849  0.8558  ...  0.7644  0.6312
# Proportion of variance  0.0422  0.0415  0.0373  0.0349  ...  0.0278  0.0190
# Cumulative proportion   0.7623  0.8039  0.8412  0.8760  ...  0.9339  0.9528
#
#                           PC14    PC15    PC16    PC17    PC18    PC19  \
# Standard deviation      0.5101  0.5001  0.4346  0.3632  0.2650  0.2023
# Proportion of variance  0.0124  0.0119  0.0090  0.0063  0.0033  0.0019
# Cumulative proportion   0.9652  0.9771  0.9861  0.9924  0.9957  0.9977
#
#                           PC20    PC21
# Standard deviation      0.1590  0.1524
# Proportion of variance  0.0012  0.0011
# Cumulative proportion   0.9989  1.0000
#
# [3 rows x 21 columns]

# %%
pcsSummary_df.iloc[2,11]
# Out:
# 0.9338587535434713

# %% [markdown]
# * Now we find that we need twelve principal components to account for more than 90% of the total variability.
# * The first two principal components account for only 49% of the total variability, and thus reducing the number of variables to two would mean losing a lot of information.

# %%
pcsComponents_df = pd.DataFrame(pcs.components_.transpose(), 
                                columns=pcsSummary_df.columns,
                                index=credit_df.iloc[:, 3:].columns
                                )
pcsComponents_df.iloc[:,:12]
# Out:
#                    PC1       PC2       PC3       PC4       PC5       PC6  \
# marital      -0.003337 -0.039156  0.203855 -0.672925  0.079728  0.044079
# age           0.010532  0.065595 -0.199232  0.666185 -0.072655 -0.045414
# hpp Sep 2005  0.172142 -0.305431 -0.019324  0.037235  0.261237  0.069579
# hpp Aug 2005  0.205673 -0.336779  0.030314  0.034596  0.098627 -0.051286
# hpp Jul 2005  0.211787 -0.345706  0.084954  0.038530 -0.043903 -0.073833
# hpp Jun 2005  0.218361 -0.346745  0.120403  0.045350 -0.154812 -0.091254
# hpp May 2005  0.221772 -0.333154  0.140803  0.042274 -0.205852 -0.057536
# hpp Apr 2005  0.216461 -0.305692  0.140546  0.039981 -0.208244 -0.027049
# abs Sep 2005  0.329807  0.167200 -0.207432 -0.075022  0.042420 -0.039367
# abs Aug 2005  0.341365  0.169110 -0.176935 -0.068405 -0.000488  0.005638
# abs Jul 2005  0.345230  0.175481 -0.116810 -0.048490 -0.024516  0.021289
# abs Jun 2005  0.349351  0.173434 -0.105239 -0.047059 -0.031114  0.077334
# abs May 2005  0.347295  0.170694 -0.088515 -0.040269 -0.006439  0.086776
# abs Apr 2005  0.340127  0.168061 -0.078717 -0.040423  0.055208 -0.035924
# app Sep 2005  0.089260  0.160744  0.393359  0.107316 -0.172785  0.225126
# app Aug 2005  0.074097  0.149590  0.426332  0.125017 -0.097831  0.193616
# app Jul 2005  0.081315  0.159818  0.387586  0.111502 -0.005569  0.312162
# app Jun 2005  0.072981  0.148112  0.327594  0.096968  0.152563  0.085035
# app May 2005  0.070466  0.141410  0.257640  0.061514  0.372309 -0.650263
# app Apr 2005  0.065174  0.131722  0.285414  0.078500  0.176077 -0.404888
# Y             0.043908 -0.188206 -0.034770  0.129626  0.748298  0.417427
#
#                    PC7       PC8       PC9      PC10      PC11      PC12
# marital      -0.020452  0.010861  0.019423 -0.018828 -0.064661  0.700072
# age           0.010592  0.009467  0.029799 -0.020064 -0.039046  0.708105
# hpp Sep 2005 -0.043959 -0.003788 -0.019685 -0.006603  0.548747  0.047943
# hpp Aug 2005  0.000004 -0.023582 -0.003202  0.002447  0.424606  0.028257
# hpp Jul 2005 -0.005317 -0.020846 -0.023344 -0.110678  0.166999  0.015716
# hpp Jun 2005 -0.005959  0.017987 -0.046729  0.010980 -0.151913  0.002561
# hpp May 2005  0.027711  0.021416  0.081382  0.040064 -0.318864 -0.021189
# hpp Apr 2005  0.112266 -0.032133  0.030208  0.056072 -0.376486 -0.018746
# abs Sep 2005 -0.028602 -0.058661  0.010273  0.007781  0.056048  0.010833
# abs Aug 2005 -0.082783 -0.043750 -0.036729 -0.135462  0.030577  0.003059
# abs Jul 2005 -0.141522  0.080220 -0.124064  0.097320  0.004741  0.001841
# abs Jun 2005 -0.045836  0.025506  0.123915  0.035860 -0.031568 -0.016113
# abs May 2005  0.111437 -0.065378 -0.004404  0.050388 -0.063584 -0.014922
# abs Apr 2005  0.156450  0.088473  0.016822 -0.000285 -0.083244 -0.019466
# app Sep 2005 -0.287457  0.031103 -0.235808 -0.739689  0.026410 -0.017380
# app Aug 2005 -0.279329  0.405094 -0.293396  0.580616  0.110912  0.024211
# app Jul 2005  0.193623 -0.009731  0.776578  0.018797  0.138185 -0.015638
# app Jun 2005  0.648455 -0.402592 -0.439629  0.070060  0.035235  0.027917
# app May 2005  0.177539  0.494233  0.064432 -0.175304 -0.050735 -0.021825
# app Apr 2005 -0.489406 -0.631334  0.112068  0.170411 -0.058202 -0.004026
# Y            -0.166518  0.048340 -0.028746 -0.032860 -0.403897 -0.030656

# %%
pcsComponents_df.PC1.idxmax()
# Out:
# 'abs Jun 2005'

# %%
pcsComponents_df.PC1.nlargest(3)
# Out:
# abs Jun 2005    0.349351
# abs May 2005    0.347295
# abs Jul 2005    0.345230
# Name: PC1, dtype: float64

# %%
pcsComponents_df.PC1.idxmin()
# Out:
# 'marital'

# %%
pcsComponents_df.PC1.nsmallest(3)
# Out:
# marital   -0.003337
# age        0.010532
# Y          0.043908
# Name: PC1, dtype: float64

# %% [markdown]
# ***'abs Jun 2005'***

# %%
pcsComponents_df.PC2.idxmax()
# Out:
# 'abs Jul 2005'

# %%
pcsComponents_df.PC2.nlargest(3)
# Out:
# abs Jul 2005    0.175481
# abs Jun 2005    0.173434
# abs May 2005    0.170694
# Name: PC2, dtype: float64

# %%
pcsComponents_df.PC2.idxmin()
# Out:
# 'hpp Jun 2005'

# %%
pcsComponents_df.PC2.nsmallest(3)
# Out:
# hpp Jun 2005   -0.346745
# hpp Jul 2005   -0.345706
# hpp Aug 2005   -0.336779
# Name: PC2, dtype: float64

# %% [markdown]
# ***'hpp Jun 2005'***

# %%
pcsComponents_df.PC3.idxmax()
# Out:
# 'app Aug 2005'

# %%
pcsComponents_df.PC3.nlargest(3)
# Out:
# app Aug 2005    0.426332
# app Sep 2005    0.393359
# app Jul 2005    0.387586
# Name: PC3, dtype: float64

# %%
pcsComponents_df.PC3.idxmin()
# Out:
# 'abs Sep 2005'

# %%
pcsComponents_df.PC3.nsmallest(3)
# Out:
# abs Sep 2005   -0.207432
# age            -0.199232
# abs Aug 2005   -0.176935
# Name: PC3, dtype: float64

# %% [markdown]
# ***'app Aug 2005'***

# %%
print('*'*55,'End','*'*55)
# Out:
# ******************************************************* End *******************************************************
